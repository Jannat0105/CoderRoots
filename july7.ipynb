# %%
import pandas as pd

# %%
data=pd.read_csv('neet_data.csv')

# %%
data
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  object
#  1   retweet_count        47381 non-null  int64
#  2   source               47362 non-null  object
#  3   user_id              47381 non-null  int64
#  4   user_name            47380 non-null  object
#  5   user_description     36510 non-null  object
#  6   user_follower_count  47381 non-null  int64
#  7   user_friends_count   47381 non-null  int64
#  8   user_location        26247 non-null  object
#  9   user_verified        47381 non-null  bool
#  10  user_url             9280 non-null   object
#  11  tweet                47381 non-null  object
#  12  length_of_tweet      47381 non-null  int64
# dtypes: bool(1), int64(5), object(7)
# memory usage: 4.4+ MB

# %%
sorted=data.sort_values(by='retweet_count', ascending=False)
sorted
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
# ...                    ...            ...                  ...
# 47347  2020-10-30 15:48:45              0        WordPress.com
# 47348  2020-10-30 15:48:43              0        WordPress.com
# 47349  2020-10-30 15:48:42              0        WordPress.com
# 47351  2020-10-30 15:46:53              0      Twitter Web App
# 47332  2020-10-30 15:53:51              0  Twitter for Android
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# ...

# %%
sorted[['source', 'user_name', 'user_follower_count',
        'tweet', 'created_at', 'user_url']].head(1)
# Out:
#                    source                             user_name  \
# 32860  Twitter for iPhone  \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
#
#        user_follower_count                                              tweet  \
# 32860                   62  RT @JoeBiden: America, I\xe2\x80\x99m honored ...
#
#                 created_at                 user_url
# 32860  2020-11-08 05:30:01  https://t.co/cHZdP4uOdu

# %%
print("the top 10 retweet count sum is:",sorted[['retweet_count']].head(10).sum())
# Out:
# the top 10 retweet count sum is: retweet_count    2652225
# dtype: int64

# %%
sorted.head(10)
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
# 16277  2020-10-25 14:14:37         137480  Twitter for Android
# 37849  2020-11-04 23:18:55         137374      Twitter Web App
# 37640  2020-11-05 04:09:52         137367  Twitter for Android
# 37071  2020-11-05 12:17:30         137367   Twitter for iPhone
# 14527  2020-10-26 13:28:21         129080  Twitter for Android
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# 33262  1099388669448867842                           Neet\xf0\x9f\x83\x8fPeet
# ...

# %%
android_tweets = sorted[sorted['source'] == 'Twitter for Android']
count_android = android_tweets.shape[0]
count_android
sum_android_retweets=android_tweets['retweet_count'].sum()
sum_android_retweets
# Out:
# np.int64(9386742)

# %%
sorted.loc[sorted['user_follower_count'].idxmax(), ['user_name', 'user_location']]
# Out:
# user_name         NDTV
# user_location    India
# Name: 44367, dtype: object

# %%
data.insert(len(data.columns), 'followers_friend_ratio', data['user_follower_count'] / data['user_friends_count'])

data
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
data
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
data.isna().sum()
# Out:
# created_at                    0
# retweet_count                 0
# source                       19
# user_id                       0
# user_name                     1
# user_description          10871
# user_follower_count           0
# user_friends_count            0
# user_location             21134
# user_verified                 0
# user_url                  38101
# tweet                         0
# length_of_tweet               0
# followers_friend_ratio      147
# dtype: int64

# %%
data['user_description'].fillna('Twitter user', inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3404\384041053.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['user_description'].fillna('Twitter user', inplace=True)

# %%
data
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
data.dropna(axis=1, inplace= True)

# %%
data
# Out:
#                 created_at  retweet_count              user_id  \
# 0      2020-10-31 14:10:28            141  1250294694937915394
# 1      2020-10-31 14:10:11              1             57059492
# 2      2020-10-31 14:09:48            141           1016022678
# 3      2020-10-31 14:09:41            141  1085818329816883201
# 4      2020-10-31 14:09:22              0  1227501071490113537
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  1168840190426632192
# 47377  2020-10-30 15:29:35           1700           1696615807
# 47378  2020-10-30 15:28:59            167  1313330869113745413
# 47379  2020-10-30 15:28:37            270  1161551282995388416
# 47380  2020-10-30 15:28:14              0  1211810532006612992
#
#                                         user_description  user_follower_count  \
# 0                                           Twitter user                   14
# ...

# %%
data.insert(loc=2, column='is_allow', value=True)

# %%
data
# Out:
#                 created_at  retweet_count  is_allow              user_id  \
# 0      2020-10-31 14:10:28            141      True  1250294694937915394
# 1      2020-10-31 14:10:11              1      True             57059492
# 2      2020-10-31 14:09:48            141      True           1016022678
# 3      2020-10-31 14:09:41            141      True  1085818329816883201
# 4      2020-10-31 14:09:22              0      True  1227501071490113537
# ...                    ...            ...       ...                  ...
# 47376  2020-10-30 15:29:35              0      True  1168840190426632192
# 47377  2020-10-30 15:29:35           1700      True           1696615807
# 47378  2020-10-30 15:28:59            167      True  1313330869113745413
# 47379  2020-10-30 15:28:37            270      True  1161551282995388416
# 47380  2020-10-30 15:28:14              0      True  1211810532006612992
#
#                                         user_description  user_follower_count  \
# ...

# %%
data.drop(columns='tweet', inplace=True)
data
# Out:
#                 created_at  retweet_count  is_allow              user_id  \
# 0      2020-10-31 14:10:28            141      True  1250294694937915394
# 1      2020-10-31 14:10:11              1      True             57059492
# 2      2020-10-31 14:09:48            141      True           1016022678
# 3      2020-10-31 14:09:41            141      True  1085818329816883201
# 4      2020-10-31 14:09:22              0      True  1227501071490113537
# ...                    ...            ...       ...                  ...
# 47376  2020-10-30 15:29:35              0      True  1168840190426632192
# 47377  2020-10-30 15:29:35           1700      True           1696615807
# 47378  2020-10-30 15:28:59            167      True  1313330869113745413
# 47379  2020-10-30 15:28:37            270      True  1161551282995388416
# 47380  2020-10-30 15:28:14              0      True  1211810532006612992
#
#                                         user_description  user_follower_count  \
# ...

# %%
data['created_at'] = pd.to_datetime(data['created_at'], errors='coerce').dt.strftime('%B %Y')
